# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("breast-cancer-wisconsin-data_data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.info() # Dataset Information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# **Pie Chart**

# %%
# Data for the pie chart

labels =['B','M']
sizes = df['diagnosis'].value_counts() 
colors = ['blue', 'yellow']
explode = (0, 0) 


# Create a pie chart

plt.pie(sizes, labels=labels, colors=colors, explode=explode, autopct='%1.1f%%', startangle=90)


plt.axis('equal') 
plt.title('Diagnosis Distribution')


# Display the pie chart
plt.show()

# %% [markdown]
# # 5. Data Preprocessing

# %%
df.isnull().sum()   # Missing Values
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# **Removing irrelevant features**

# %%
df=df.drop(['id','Unnamed: 32'], axis=1)

# %%
# Map "M" and "B" to 1 and 0 

df['diagnosis']= df['diagnosis']  .map({'M': 1, 'B': 0})

# %%
X = df.drop(['diagnosis'], axis=1)  
y = df['diagnosis']

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training and testing sets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

# %%
#Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# decision tree
model = DecisionTreeClassifier(random_state=45)

# %% [markdown]
# **Model Training**

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=45)

# %%
# Make predictions on the test set

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 91.23%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.93        72
#            1       0.92      0.83      0.88        42
#
#     accuracy                           0.91       114
#    macro avg       0.91      0.90      0.90       114
# weighted avg       0.91      0.91      0.91       114

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 6))

sns.heatmap(
    cm, annot=True, fmt='d', cmap='magma', linewidths=0.4, square=True, cbar=True,
    xticklabels=["B", "M"],
    yticklabels=["B", "M"]
)

plt.xlabel('Predicted', fontsize=14, fontweight='bold')
plt.ylabel('Actual', fontsize=14, fontweight='bold')
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.yticks(rotation=360)

plt.show()

# %%
#Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
df_RF = pd.read_csv("breast-cancer-wisconsin-data_data.csv")
df_RF=df_RF.drop(['id','Unnamed: 32'], axis=1) 
df_RF['diagnosis']= df_RF['diagnosis'].map({'M': 1, 'B': 0})

X = df_RF.drop(['diagnosis'], axis=1)
y = df_RF['diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

# %%
model = RandomForestClassifier(random_state=45)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=45)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 96.49%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        72
#            1       0.97      0.93      0.95        42
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='magma', linewidths=0.4, square=True, cbar=True,
    xticklabels=["B", "M"],
    yticklabels=["B", "M"]
)

plt.xlabel('Predicted', fontsize=14, fontweight='bold')
plt.ylabel('Actual', fontsize=14, fontweight='bold')
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.yticks(rotation=360)

plt.show()

# %%
#Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
df_bys = pd.read_csv("breast-cancer-wisconsin-data_data.csv")
df_bys = df_bys.drop(['id', 'Unnamed: 32'], axis=1) 
df_bys['diagnosis'] = df_bys['diagnosis'].map({'M': 1, 'B': 0})

X = df_bys.drop(['diagnosis'], axis=1)
y = df_bys['diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 93.86%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95        72
#            1       0.97      0.86      0.91        42
#
#     accuracy                           0.94       114
#    macro avg       0.95      0.92      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='magma', linewidths=0.4, square=True, cbar=True,
    xticklabels=["B", "M"],
    yticklabels=["B", "M"]
)

plt.xlabel('Predicted', fontsize=14, fontweight='bold')
plt.ylabel('Actual', fontsize=14, fontweight='bold')
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.yticks(rotation=360)

plt.show()

# %%
#ANN

# %%
from sklearn.neural_network import MLPClassifier
df_ann = pd.read_csv("breast-cancer-wisconsin-data_data.csv")
df_ann = df_ann.drop(['id', 'Unnamed: 32'], axis=1) 
df_ann['diagnosis'] = df_ann['diagnosis'].map({'M': 1, 'B': 0})
X = df_ann.drop(['diagnosis'], axis=1)
y = df_ann['diagnosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)
model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, activation='relu', solver='adam', random_state=45)
model.fit(X_train, y_train)
# Out:
# MLPClassifier(max_iter=300, random_state=45)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        72
#            1       0.95      0.88      0.91        42
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 93.86%

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='magma', linewidths=0.4, square=True, cbar=True,
    xticklabels=["B", "M"],
    yticklabels=["B", "M"]
)

plt.xlabel('Predicted', fontsize=14, fontweight='bold')
plt.ylabel('Actual', fontsize=14, fontweight='bold')
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.yticks(rotation=360)

plt.show()

# %%
# LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
df_LSTM = pd.read_csv("breast-cancer-wisconsin-data_data.csv")
df_LSTM = df_LSTM.drop(['id', 'Unnamed: 32'], axis=1)
df_LSTM['diagnosis'] = df_LSTM['diagnosis'].map({'M': 1, 'B': 0})

# %%
X = df_LSTM.drop(['diagnosis'], axis=1)
y = df_LSTM['diagnosis']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=45)

# reshape
X_train_lstm = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_lstm = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train_lstm, y_train, epochs=20, batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8120 - loss: 0.6199
# Epoch 2/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9273 - loss: 0.4205
# Epoch 3/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9404 - loss: 0.3009
# Epoch 4/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9435 - loss: 0.2321
# Epoch 5/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9555 - loss: 0.1845
# Epoch 6/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9489 - loss: 0.1717
# Epoch 7/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9702 - loss: 0.1244
# Epoch 8/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9689 - loss: 0.1279
# Epoch 9/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9724 - loss: 0.1102
# Epoch 10/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9757 - loss: 0.1000
# Epoch 11/20
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9775 - loss: 0.0931
# Epoch 12/20
# ...

# %%
y_pred_prob = model.predict(X_test_lstm)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 98.25%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        72
#            1       1.00      0.95      0.98        42
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(
    cm, annot=True, fmt='d', cmap='magma', linewidths=0.4, square=True, cbar=True,
    xticklabels=["B", "M"],
    yticklabels=["B", "M"]
)

plt.xlabel('Predicted', fontsize=14, fontweight='bold')
plt.ylabel('Actual', fontsize=14, fontweight='bold')
plt.title('Confusion Matrix', fontsize=16, fontweight='bold')
plt.yticks(rotation=360)

plt.show()
